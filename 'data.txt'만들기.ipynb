# %%
당도 = ['안 달', '달지 않은', '달지 않고', '드라이', '안 단','달달한','달달하고', '달달하지만','달짝지근','단','달콤한', '스위트','많이 단']
바디감 = ['가벼운', '라이트', '가볍', '라이트바디', '상쾌한','청량한', '가볍지만','가볍지 않은', '미디엄', '미디엄바디','진한', '진하고',  '무거운','무겁고', '헤비', '풀', '풀바디', '끈적한', '무겁지만']
산미 = ['안 신', '안 시고',  '시지 않은', '시지 않고','새콤한','상큼한', '시지만', '조금 시큼한','시고','신', '시큼한','시큼하고']
도수 = ['쎈', '약한', '3도', '4도', '5도', '6도', '7도', '8도', '9도', '10도', '11도', '12도', '13도', '14도', '15도', '16도', '17도', '18도']
단위 = ['이상', '미만', '초과', '이하']
종류 = ['레드', '화이트', '스파클링', '샴페인', '로제']
금액 = []
for i in range(1,101):
    금액.append(f'{i}만')
    금액.append(f'{i}만원')
OOV_str = '''와인 추천해줘.
와인은 처음인데 괜찮은거 추천좀.
와인 뭐 마실까?
무슨 와인 마실까?
아무 와인이나 추천해줘.
무슨 와인 살까?
맛있는 와인 추천해줘.
좋은 와인 추천해줘.
괜찮은 와인에는 뭐가 있을까?
포도주 추천해줘.
포도주는 처음인데 괜찮은거 추천좀.
포도주 뭐 마실까?
무슨 포도주 마실까?
아무 포도주나 추천해줘.
무슨 포도주 살까?
맛있는 포도주 추천해줘.
좋은 포도주 추천해줘.
괜찮은 포도주에는 뭐가 있을까?
'''
OOV_list = OOV_str.split('\n')

# %%
import random
texts = []
for oov in OOV_list:
    texts.append(oov)
for _ in range(0,2000):
    texts.append(f'/종류;{random.choice(종류)}/로 친구랑 마실만한 와인 추천해줘.\n')
    texts.append(f'이탈리아산 /당도;{random.choice(당도)}/ 와인 추천해줘!\n')
    texts.append(f'와인 처음 먹어보는데/바디감;{random.choice(바디감)}/느낌으로 추천 해줄래?\n')
    texts.append(f'저녁에 간단하게 혼술할 /산미;{random.choice(산미)}/ 와인이 있을까?\n')
    texts.append(f'아침에 회사가기 싫을 정도로/도수;{random.choice(도수)}/와인 추천해줘.\n')
    texts.append(f'친구들이랑 파티할 때 마실/금액;{random.choice(금액)}/와인 좀 추천해줘.\n')
    texts.append(f'여자친구랑 마실/당도;{random.choice(당도)}/와인 추천해줘 종류는/종류;{random.choice(종류)}/로\n')
    texts.append(f'/종류;{random.choice(종류)}/와인 중에 /바디감;{random.choice(바디감)}/한 와인 있어?\n')
    texts.append(f'/산미;{random.choice(산미)}/ 종류의/종류;{random.choice(종류)}/와인 있을까?\n')   
    texts.append(f'/종류;{random.choice(종류)}/와인 중 /도수;{random.choice(도수)}/걸로.\n')
    texts.append(f'친구들이랑 마실건데/금액;{random.choice(금액)}/정도로/종류;{random.choice(종류)}/와인 추천.\n')
    texts.append(f'파티에 어울리는/종류;{random.choice(종류)}/으로/바디감;{random.choice(바디감)}/ /산미;{random.choice(산미)}/ /도수;{random.choice(도수)}/이하의 와인 추천해줘.\n')
    texts.append(f'와인 잘 모르는데/종류;{random.choice(종류)}/와인에서/바디감;{random.choice(바디감)}/느낌의 /산미;{random.choice(산미)}//금액;{random.choice(금액)}/대 와인 추천해줘 \n')
    texts.append(f'/종류;{random.choice(종류)}/와인이면서 /바디감;{random.choice(바디감)}/ /도수;{random.choice(도수)}/ /금액;{random.choice(금액)}/대 와인 추천해줘 \n')
    texts.append(f'/종류;{random.choice(종류)}/으로/산미;{random.choice(산미)}//도수;{random.choice(도수)}/의/금액;{random.choice(금액)}/대 와인 추천해줘 \n')
    texts.append(f'/당도;{random.choice(당도)}//바디감;{random.choice(바디감)}//산미;{random.choice(산미)}//도수;{random.choice(도수)}/짜리/종류;{random.choice(종류)}/으로 추천해줘 \n')
    texts.append(f'/종류;{random.choice(종류)}/긴 한데/당도;{random.choice(당도)}//바디감;{random.choice(바디감)}/느낌의/산미;{random.choice(산미)}/와인 추천해줘/금액;{random.choice(금액)}/으로\n')
    texts.append(f'/당도;{random.choice(당도)}//바디감;{random.choice(바디감)}//도수;{random.choice(도수)}/이하/종류;{random.choice(종류)}//금액;{random.choice(금액)}/추천해줘 \n')
    texts.append(f'/종류;{random.choice(종류)}/으로 친구들이랑 마실 /당도;{random.choice(당도)}//산미;{random.choice(산미)}//도수;{random.choice(도수)}/ /금액;{random.choice(금액)}/으로 추천해줘 \n')
    texts.append(f'/종류;{random.choice(종류)}/으로/바디감;{random.choice(바디감)}//산미;{random.choice(산미)}//도수;{random.choice(도수)}/의 /금액;{random.choice(금액)}/와인 추천해줘 \n')
    texts.append(f'/당도;{random.choice(당도)}//바디감;{random.choice(바디감)}//산미;{random.choice(산미)}//도수;{random.choice(도수)}/짜리/종류;{random.choice(종류)}/으로 추천해줘 \n')
    texts.append(f'화날 때 먹을/당도;{random.choice(당도)}//바디감;{random.choice(바디감)}/와인 있어? \n')
    texts.append(f'애인이랑 분위기 내고싶을 떄 먹은 /산미;{random.choice(산미)}/ /도수;{random.choice(도수)}/ 와인 추천해줘 \n')
    texts.append(f'/산미;{random.choice(산미)}/ /금액;{random.choice(금액)}/이하 취하지 않을 정도 기분만 낼 수 있는 와인 추천해줘 \n')
    texts.append(f'아빠 승진 축하를 위해 마실건데/도수;{random.choice(도수)}/ 이상의 /금액;{random.choice(금액)}/ 이상의 고급 와인 추천해줘 \n')
    texts.append(f'/당도;{random.choice(당도)}/ /바디감;{random.choice(바디감)}/ /산미;{random.choice(산미)}/ 와인 추천해줘 \n')
    texts.append(f'친구들이랑 먹을 /당도;{random.choice(당도)}/ /바디감;{random.choice(바디감)}/ /도수;{random.choice(도수)}/ 와인 추천해줘 \n')
    texts.append(f'/당도;{random.choice(당도)}/ /바디감;{random.choice(바디감)}/ /금액;{random.choice(금액)}/ 와인 추천해줘 \n')
    texts.append(f'깔끔하게 먹을 /당도;{random.choice(당도)}/ /산미;{random.choice(산미)}/살짝 추가된/도수;{random.choice(도수)}/의 와인 추천해줘 \n')
    texts.append(f'/당도;{random.choice(당도)}/ /산미;{random.choice(산미)}/ /금액;{random.choice(금액)}/정도 와인 추천해줘 \n')
    texts.append(f'/당도;{random.choice(당도)}/맛있는/도수;{random.choice(도수)}/ /금액;{random.choice(금액)}/대 가성비 좋은 와인 추천해줘 \n')
    texts.append(f'/바디감;{random.choice(바디감)}/ /산미;{random.choice(산미)}/ /도수;{random.choice(도수)}/와인 추천해줘 \n')
    texts.append(f'/바디감;{random.choice(바디감)}/ /산미;{random.choice(산미)}/ /금액;{random.choice(금액)}/대의 와인 추천해줘 \n')
    texts.append(f'/바디감;{random.choice(바디감)}/ /도수;{random.choice(도수)}/의/금액;{random.choice(금액)}/ 와인 추천해줘 \n')
    texts.append(f'/산미;{random.choice(산미)}/면서/도수;{random.choice(도수)}/ /금액;{random.choice(금액)}/ 와인 추천해줘 \n')
    texts.append(f'포도향이 많이 나는 /당도;{random.choice(당도)}/ /바디감;{random.choice(바디감)}/ /산미;{random.choice(산미)}/ /도수;{random.choice(도수)}/ 와인 추천해줘 \n')
    texts.append(f'/당도;{random.choice(당도)}/ /바디감;{random.choice(바디감)}/ /산미;{random.choice(산미)}/ /금액;{random.choice(금액)}/ 목넘김이 좋은 와인 추천해줘 \n')
    texts.append(f'/당도;{random.choice(당도)}/ /바디감;{random.choice(바디감)}/ /도수;{random.choice(도수)}/ /금액;{random.choice(금액)}/  와인 추천해줘 \n')
    texts.append(f'/당도;{random.choice(당도)}/ /산미;{random.choice(산미)}/ /도수;{random.choice(도수)}/의 /금액;{random.choice(금액)}/대 와인 추천해줘 \n')
    texts.append(f'/바디감;{random.choice(바디감)}/ /산미;{random.choice(산미)}/ /도수;{random.choice(도수)}/의 /금액;{random.choice(금액)}/와인 추천해줘 \n')
    texts.append(f'/당도;{random.choice(당도)}/ /바디감;{random.choice(바디감)}/ 느낌으로/산미;{random.choice(산미)}/ /도수;{random.choice(도수)}/ /금액;{random.choice(금액)}/와인 추천해줘 \n')
    texts.append(f'가볍게 먹을/당도;{random.choice(당도)}/ /산미;{random.choice(산미)}/않은 와인 있으면 추천해줘 \n')
    texts.append(f'/당도;{random.choice(당도)}/맛이 강하게 느껴지는/ /도수;{random.choice(도수)}/이상 와인추천해줘 \n')
    texts.append(f'/당도;{random.choice(당도)}/ /금액;{random.choice(금액)}/대 와인추천해줘 \n')
    texts.append(f'/바디감;{random.choice(바디감)}/ /산미;{random.choice(산미)}/ 와인추천해줘 \n')
    texts.append(f'기분만 낼 정도의 /바디감;{random.choice(바디감)}/ /도수;{random.choice(도수)}/정도 와인 있을까? \n')
    texts.append(f'우울한 기분을 달래줄 /바디감;{random.choice(바디감)}/ /금액;{random.choice(금액)}/대의 와인 추천해줘 \n')
    texts.append(f'친구들이랑 마실건데/금액;{random.choice(금액)}/정도로/종류;{random.choice(종류)}/와인 추천\n')
    texts.append(f'/종류;{random.choice(종류)}/에/바디감;{random.choice(바디감)}/하고/당도;{random.choice(당도)}/ 와인!!! \n')
    texts.append(f'엄마 선물로 구매할/당도;{random.choice(당도)}// 산미;{random.choice(산미)}//종류;{random.choice(종류)}/와인 보여줘!\n')
    texts.append(f'놀러가서 마실/도수;{random.choice(도수)}//종류;{random.choice(종류)}/와인 당도는/당도;{random.choice(당도)}/았으면 좋겠어\n')
    texts.append(f'/금액;{random.choice(금액)}/정도의/당도;{random.choice(당도)}/한/종류;{random.choice(종류)}/와인\n')
    texts.append(f'아빠랑 마실/산미;{random.choice(산미)}/고/바디감;{random.choice(바디감)}//종류;{random.choice(종류)}/와인 찾아줘\n')
    texts.append(f'술 배틀용/도수;{random.choice(도수)}/이상의/바디감;{random.choice(바디감)}//종류;{random.choice(종류)}/와인\n')
    texts.append(f'여자친구랑 싸우고 화해할/바디감;{random.choice(바디감)}/고/금액;{random.choice(금액)}/정도의 와인 추천해줘/종류;{random.choice(종류)}/로\n')
    texts.append(f'여행가서 마실/도수;{random.choice(도수)}/하고/산미;{random.choice(산미)}//종류;{random.choice(종류)}/와인이 있어? \n')
    texts.append(f'/종류;{random.choice(종류)}/와인 중에서 마실 때/산미;{random.choice(산미)}//금액;{random.choice(금액)}/와인\n')
    texts.append(f'점심 나가서 먹을 정도로/도수;{random.choice(도수)}/ /금액;{random.choice(금액)}/정도의/종류;{random.choice(종류)}/와인 추천\n')
    texts.append(f'/당도;{random.choice(당도)}//산미;{random.choice(산미)}//바디감;{random.choice(바디감)}/ / 종류;{random.choice(종류)}/ 와인 있을까?\n')
    texts.append(f'혼술 하기 좋은 /당도;{random.choice(당도)}/않고 /바디감;{random.choice(바디감)}/ /도수;{random.choice(도수)}/ /종류;{random.choice(종류)}/ 추천해줘\n')
    texts.append(f'/종류;화이트/ /당도;{random.choice(당도)}/ /바디감;{random.choice(바디감)}/ /금액;{random.choice(금액)}/ 와인 추천해주셈\n')
    texts.append(f'처음 마셔보는데 /당도;{random.choice(당도)}/ /산미;{random.choice(산미)}/않은 /도수;{random.choice(도수)}/의 /종류;{random.choice(종류)}/와인 있어?\n')
    texts.append(f'/종류;{random.choice(종류)}/와인인데 /당도;{random.choice(당도)}/ /산미;{random.choice(산미)}/ /금액:{random.choice(금액)}/ 와인 추천해줘\n')
    texts.append(f'여자친구들끼리 먹을 건데/종류;{random.choice(종류)}/로/당도;{random.choice(당도)}/ /도수;{random.choice(도수)}/의 /금액;{random.choice(금액)}/ 와인 추천해줘')

# %%
texts
# Out:
# ['와인 추천해줘.',
#  '와인은 처음인데 괜찮은거 추천좀.',
#  '와인 뭐 마실까?',
#  '무슨 와인 마실까?',
#  '아무 와인이나 추천해줘.',
#  '무슨 와인 살까?',
#  '맛있는 와인 추천해줘.',
#  '좋은 와인 추천해줘.',
#  '괜찮은 와인에는 뭐가 있을까?',
#  '포도주 추천해줘.',
#  '포도주는 처음인데 괜찮은거 추천좀.',
#  '포도주 뭐 마실까?',
#  '무슨 포도주 마실까?',
#  '아무 포도주나 추천해줘.',
#  '무슨 포도주 살까?',
#  '맛있는 포도주 추천해줘.',
#  '좋은 포도주 추천해줘.',
#  '괜찮은 포도주에는 뭐가 있을까?',
#  '',
#  '/종류;로제/로 친구랑 마실만한 와인 추천해줘.\n',
#  '이탈리아산 /당도;안 달/ 와인 추천해줘!\n',
#  '와인 처음 먹어보는데/바디감;무겁고/느낌으로 추천 해줄래?\n',
#  '저녁에 간단하게 혼술할 /산미;신/ 와인이 있을까?\n',
#  '아침에 회사가기 싫을 정도로/도수;11도/와인 추천해줘.\n',
#  '친구들이랑 파티할 때 마실/금액;88만/와인 좀 추천해줘.\n',
#  '여자친구랑 마실/당도;많이 단/와인 추천해줘 종류는/종류;샴페인/로\n',
#  '/종류;로제/와인 중에 /바디감;진한/한 와인 있어?\n',
#  '/산미;안 시고/ 종류의/종류;로제/와인 있을까?\n',
#  '/종류;스파클링/와인 중 /도수;13도/걸로.\n',
#  '친구들이랑 마실건데/금액;58만원/정도로/종류;스파클링/와인 추천.\n',
#  '파티에 어울리는/종류;화이트/으로/바디감;가벼운/ /산미;신/ /도수;약한/이하의 와인 추천해줘.\n',
#  '와인 잘 모르는데/종류;스파클링/와인에서/바디감;무겁고/느낌의 /산미;시큼하고//금액;97만원/대 와인 추천해줘 \n',
#  '/종류;샴페인/와인이면서 /바디감;가벼운/ /도수;16도/ /금액;14만원/대 와인 추천해줘 \n',
# ...

# %%
len(texts)
# Out:
# 128019

# %%
texts = set(texts)
len(texts)
# Out:
# 83924

# %%
with open('./dataset/data.txt','w') as f:
    for text in texts:
        f.write(text)
